# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.s3 import S3Uploader
from sagemaker.pytorch import PyTorch

import os
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
sagemaker_session = sagemaker.Session()
role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %%
pytorch_estimator = PyTorch(entry_point = 'train.py',
                            source_dir = '../scripts'
                            instance_type='ml.p3.2xlarge',
                            role = role,
                            instance_count=1,
                            framework_version='1.8.0',
                            py_version='py3',
                            hyperparameters = {'epochs': 100, 
                                               'batch-size': 64, 
                                               'learning-rate': 0.003})

# %%
pytorch_estimator.fit({'train': 's3://responsibleai/data/churn.csv'})
# Out:
# 2022-02-28 19:12:34 Starting - Starting the training job...
# 2022-02-28 19:12:36 Starting - Launching requested ML instancesProfilerReport-1646075553: InProgress
# .........
# 2022-02-28 19:14:27 Starting - Preparing the instances for training......
# 2022-02-28 19:15:28 Downloading - Downloading input data
# 2022-02-28 19:15:28 Training - Downloading the training image..............................
# 2022-02-28 19:20:29 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-02-28 19:20:26,776 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-02-28 19:20:26,800 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-02-28 19:20:28,225 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-02-28 19:20:28,793 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 64,
#         "learning-rate": 0.003,
#         "epochs": 100
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2022-02-28-19-12-33-865",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-247385444016/pytorch-training-2022-02-28-19-12-33-865/source/sourcedir.tar.gz",
#     "module_name": "churn",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "churn.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":64,"epochs":100,"learning-rate":0.003}
# SM_USER_ENTRY_POINT=churn.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=churn
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-247385444016/pytorch-training-2022-02-28-19-12-33-865/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":64,"epochs":100,"learning-rate":0.003},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2022-02-28-19-12-33-865","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-247385444016/pytorch-training-2022-02-28-19-12-33-865/source/sourcedir.tar.gz","module_name":"churn","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"churn.py"}
# SM_USER_ARGS=["--batch-size","64","--epochs","100","--learning-rate","0.003"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH-SIZE=64
# SM_HP_LEARNING-RATE=0.003
# SM_HP_EPOCHS=100
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 churn.py --batch-size 64 --epochs 100 --learning-rate 0.003
# Namespace(current_host='algo-1', hosts=['algo-1'], model_dir='/opt/ml/model', output_data_dir='/opt/ml/output/data', sm_model_dir='/opt/ml/model', train='/opt/ml/input/data/train')
# /opt/ml/input/data/train
# [2022-02-28 19:20:33.017 algo-1:26 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-02-28 19:20:33.162 algo-1:26 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2022-02-28 19:20:33.163 algo-1:26 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-02-28 19:20:33.163 algo-1:26 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-02-28 19:20:33.164 algo-1:26 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-02-28 19:20:33.164 algo-1:26 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-02-28 19:20:33.599 algo-1:26 INFO hook.py:584] name:0.weight count_params:832
# [2022-02-28 19:20:33.599 algo-1:26 INFO hook.py:584] name:0.bias count_params:64
# [2022-02-28 19:20:33.600 algo-1:26 INFO hook.py:584] name:2.weight count_params:4096
# [2022-02-28 19:20:33.600 algo-1:26 INFO hook.py:584] name:2.bias count_params:64
# [2022-02-28 19:20:33.600 algo-1:26 INFO hook.py:584] name:4.weight count_params:64
# [2022-02-28 19:20:33.600 algo-1:26 INFO hook.py:584] name:4.bias count_params:1
# [2022-02-28 19:20:33.600 algo-1:26 INFO hook.py:586] Total Trainable Params: 5121
# [2022-02-28 19:20:33.600 algo-1:26 INFO hook.py:413] Monitoring the collections: losses
# [2022-02-28 19:20:33.603 algo-1:26 INFO hook.py:476] Hook is writing from the hook with pid: 26
# Epoch 0 - Training loss: 0.43726603044196966
# Epoch 1 - Training loss: 0.3576710416935384
# Epoch 2 - Training loss: 0.33914266908541324
# Epoch 3 - Training loss: 0.3323130869306624
# Epoch 4 - Training loss: 0.3292907426133752
# Epoch 5 - Training loss: 0.3258932107128203
# Epoch 6 - Training loss: 0.32363252313807606
# Epoch 7 - Training loss: 0.3225824484601617
# Epoch 8 - Training loss: 0.3205693163909018
# Epoch 9 - Training loss: 0.31880625286139547
# Epoch 10 - Training loss: 0.31691677439957855
# Epoch 11 - Training loss: 0.3179988564457744
# Epoch 12 - Training loss: 0.31452031172811984
# Epoch 13 - Training loss: 0.31342993886210024
# Epoch 14 - Training loss: 0.31256052013486624
# Epoch 15 - Training loss: 0.30983347008004786
# Epoch 16 - Training loss: 0.30888627930544316
# Epoch 17 - Training loss: 0.30853569209575654
# Epoch 18 - Training loss: 0.3076091418042779
# Epoch 19 - Training loss: 0.3068100023083389
# Epoch 20 - Training loss: 0.30468046297319235
# Epoch 21 - Training loss: 0.30326836062595247
# Epoch 22 - Training loss: 0.29990750914439557
# Epoch 23 - Training loss: 0.2983188958372921
# Epoch 24 - Training loss: 0.2970258506480604
# Epoch 25 - Training loss: 0.2966073320247233
# Epoch 26 - Training loss: 0.2947651526890695
# Epoch 27 - Training loss: 0.2908246916718781
# Epoch 28 - Training loss: 0.28998794802464545
# Epoch 29 - Training loss: 0.29172039800323546
# Epoch 30 - Training loss: 0.2859232857357711
# Epoch 31 - Training loss: 0.2847970805130899
# Epoch 32 - Training loss: 0.28337392769753933
# Epoch 33 - Training loss: 0.2815882802940905
# Epoch 34 - Training loss: 0.27795729227364063
# Epoch 35 - Training loss: 0.27959277951158584
# Epoch 36 - Training loss: 0.27442575921304524
# Epoch 37 - Training loss: 0.2730200029909611
# Epoch 38 - Training loss: 0.271102630905807
# Epoch 39 - Training loss: 0.27226037383079527
# Epoch 40 - Training loss: 0.2671817837748677
# Epoch 41 - Training loss: 0.26640260736458005
# Epoch 42 - Training loss: 0.2624500480014831
# Epoch 43 - Training loss: 0.26105002756230533
# Epoch 44 - Training loss: 0.2600953231099993
# Epoch 45 - Training loss: 0.2587096369359642
# Epoch 46 - Training loss: 0.2586809016764164
# Epoch 47 - Training loss: 0.25720385783351957
# Epoch 48 - Training loss: 0.25590252596884966
# Epoch 49 - Training loss: 0.2529623470734805
# Traceback (most recent call last):
#   File "churn.py", line 148, in <module>
#     model.save(os.path.join(args.sm_model_dir, '000000001'))
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 977, in __getattr__
#     type(self).__name__, name))
# AttributeError: 'Sequential' object has no attribute 'save'
# 2022-02-28 19:21:44,374 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 churn.py --batch-size 64 --epochs 100 --learning-rate 0.003"
# Traceback (most recent call last):
#   File "churn.py", line 148, in <module>
#     model.save(os.path.join(args.sm_model_dir, '000000001'))
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 977, in __getattr__
#     type(self).__name__, name))
# AttributeError: 'Sequential' object has no attribute 'save'
#
# 2022-02-28 19:22:11 Uploading - Uploading generated training model
# 2022-02-28 19:22:11 Failed - Training job failed
# ProfilerReport-1646075553: Stopping
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-28-ec3767a4dfe6> in <module>
# ----> 1 pytorch_estimator.fit({'train': 's3://responsibleai/data/churn.csv'})
#
# /opt/conda/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     690         self.jobs.append(self.latest_training_job)
#     691         if wait:
# --> 692             self.latest_training_job.wait(logs=logs)
#     693
#     694     def _compilation_job_name(self):
#
# /opt/conda/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1653         # If logs are requested, call logs_for_jobs.
#    1654         if logs != "None":
# -> 1655             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1656         else:
#    1657             self.sagemaker_session.wait_for_job(self.job_name)
#
# /opt/conda/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3777
#    3778         if wait:
# -> 3779             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3780             if dot:
#    3781                 print()
#
# /opt/conda/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3336                 ),
#    3337                 allowed_statuses=["Completed", "Stopped"],
# -> 3338                 actual_status=status,
#    3339             )
#    3340
#
# UnexpectedStatusException: Error for Training job pytorch-training-2022-02-28-19-12-33-865: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 churn.py --batch-size 64 --epochs 100 --learning-rate 0.003"
# Traceback (most recent call last):
#   File "churn.py", line 148, in <module>
#     model.save(os.path.join(args.sm_model_dir, '000000001'))
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 977, in __getattr__
#     type(self).__name__, name))
# AttributeError: 'Sequential' object has no attribute 'save'
